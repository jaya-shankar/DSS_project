# %% [markdown]
# <a href="https://colab.research.google.com/github/jaya-shankar/DSS_project/blob/main/DSS_assignment_dataset_combine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !rm -rf DSS_project

# !git clone https://github.com/jaya-shankar/DSS_project.git
# Out:
# Cloning into 'DSS_project'...
# remote: Enumerating objects: 102, done.
# remote: Counting objects: 100% (102/102), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 102 (delta 51), reused 73 (delta 26), pack-reused 0
# Receiving objects: 100% (102/102), 28.46 MiB | 17.77 MiB/s, done.
# Resolving deltas: 100% (51/51), done.

# %%
import pandas as pd

# %%
root_path = "/content/DSS_project/raw_datasets"

# %%
df = pd.read_csv(f"{root_path}/COVID-19_Hospital_Data_Coverage_Detail.csv")
df
# Out:
#      state     ccn                                  facility_name  \
# 0       AZ  030108         CORE INSTITUTE SPECIALTY HOSPITAL, THE
# 1       CO  061310              SEDGWICK COUNTY MEMORIAL HOSPITAL
# 2       FL  102012  PAM HEALTH SPECIALTY HOSPITAL OF JACKSONVILLE
# 3       IA  160124                      LAKES REGIONAL HEALTHCARE
# 4       IN  151320                                  IU HEALTH JAY
# ...    ...     ...                                            ...
# 5851    LA  191310                   FRANKLIN FOUNDATION HOSPITAL
# 5852    PA  390201                LEHIGH VALLEY HOSPITAL - POCONO
# 5853    WI  520038           AURORA MEDICAL CTR WASHINGTON COUNTY
# 5854    GA  110010                      EMORY UNIVERSITY HOSPITAL
# 5855    ND  352004                        VIBRA HOSPITAL OF FARGO
#
#               street_address              city  zip_code  fips_county  \
# 0     6501 NORTH 19TH AVENUE           PHOENIX   85015.0           13
# ...

# %%
df.provider_subtype.unique()
# Out:
# array(['Short Term', 'Critical Access Hospitals', 'Long Term',
#        'Psychiatric', 'Rehabilitation', 'Childrens Hospitals',
#        "Medicaid Only Children's Psychiatric"], dtype=object)

# %%
general_df = pd.read_csv(f"{root_path}/hospital_count.csv")

# %%
general_df_states = set(general_df.state_code)
general_df_states
general_df.set_index("state_code",inplace=True)

# %% [markdown]
# ## Adding roads data

# %%
roads_df = pd.read_csv(f"{root_path}/roads_measure.csv",encoding='utf-16' )
roads_df
# Out:
#                    State code               Measure  Year        Value
# 0          United States  USA  Miles of public road  2020  4192478.508
# 1                Alabama   AL  Miles of public road  2020   100170.897
# 2                 Alaska   AK  Miles of public road  2020    17680.928
# 3                Arizona   AZ  Miles of public road  2020    66968.047
# 4               Arkansas   AR  Miles of public road  2020    99246.486
# 5             California   CA  Miles of public road  2020   175562.156
# 6               Colorado   CO  Miles of public road  2020    89207.321
# 7            Connecticut   CT  Miles of public road  2020    21575.040
# 8               Delaware   DE  Miles of public road  2020     6525.610
# 9   District of Columbia   DC  Miles of public road  2020     1515.913
# 10               Florida   FL  Miles of public road  2020   123487.605
# 11               Georgia   GA  Miles of public road  2020   128571.803
# ...

# %%
roads_dic = {}
for state in general_df_states:
  try:
    roads_dic[state] = float(roads_df[roads_df.code==state].Value)
  except:
    roads_dic[state] = None
roads_dic
# Out:
# {'AK': 17680.928,
#  'AL': 100170.897,
#  'AR': 99246.486,
#  'AZ': 66968.047,
#  'CA': 175562.156,
#  'CO': 89207.321,
#  'CT': 21575.04,
#  'DC': 1515.913,
#  'DE': 6525.61,
#  'FL': 123487.605,
#  'GA': 128571.803,
#  'GU': None,
#  'HI': 4501.037,
#  'IA': 114838.394,
#  'ID': 53281.228,
#  'IL': 145992.87,
#  'IN': 97110.087,
#  'KS': 140112.204,
#  'KY': 80006.165,
#  'LA': 63746.046,
#  'MA': 36815.231,
#  'MD': 32430.478,
#  'ME': 22851.46,
#  'MI': 122040.288,
#  'MN': 141956.661,
#  'MO': 132518.842,
#  'MS': 77512.154,
#  'MT': 73489.786,
#  'NC': 107954.343,
#  'ND': 88429.108,
#  'NE': 95331.079,
#  'NH': 16193.067,
#  'NJ': 38990.5,
#  'NM': 72092.437,
#  'NV': 47793.433,
#  'NY': 114205.26,
#  'OH': 122991.748,
#  'OK': 115078.883,
#  'OR': 78990.7,
#  'PA': 120845.435,
#  'PR': 19916.489,
#  'RI': 6024.804,
#  'SC': 79189.65,
#  'SD': 81697.382,
#  'TN': 96181.889,
#  'TX': 316567.47,
#  'UT': 48811.503,
#  'VA': 75527.129,
#  'VI': None,
#  'VT': 14248.412,
# ...

# %%
general_df["miles_of_road"] = 0
for i in general_df.index:
  general_df["miles_of_road"][i] = roads_dic[i]

# %% [markdown]
# ## Adding politics data

# %%
politics_df = pd.read_csv(f"{root_path}/democratic_vs_republican_votes_by_usa_state_2020.csv")
politics_df.columns
# Out:
# Index(['state', 'DEM', 'REP', 'usa_state', 'usa_state_code',
#        'percent_democrat'],
#       dtype='object')

# %%
dem_dic = {}
for state in general_df_states:
  try:
    dem_dic[state] = float(politics_df[politics_df.usa_state_code==state].percent_democrat)
  except:
    dem_dic[state] = None
dem_dic

# %%
general_df["percent_democrat"] = 0
for i in general_df.index:
  general_df["percent_democrat"][i] = dem_dic[i]

# %% [markdown]
# ## Adding Population Data

# %%
population_df = pd.read_csv(f"{root_path}/PopulationEstimates.csv")
population_df.columns
# Out:
# Index(['FIPStxt', 'State', 'Area name', 'Rural-urban continuum code 2013',
#        'Population 2020'],
#       dtype='object')

# %%
population_df.dropna(subset = ['Population 2020'], inplace=True)

# %%
def sum_population(state_code):
  # print(state_code)
  
  l = list(population_df[population_df.State==state_code]['Population 2020'])
  f = lambda x : int(x.replace(",",""))
  l = list(map(f,l))
  p = sum(l)
  return p

# %%
popu_dic = {}
for state in general_df_states:

  popu_dic[state] = sum_population(state)
popu_dic

# %%
general_df["population"] = 0
for i in general_df.index:
  general_df["population"][i] = popu_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
general_df.sort_index(level=1)

# %% [markdown]
# ## Adding Average Income Data

# %%
avg_income_df = pd.read_csv(f"{root_path}/avg_income.csv")
avg_income_df.columns
# Out:
# Index(['State', '2020 Real per capita personal income',
#        '2015 Real per capita personal income',
#        '2015-2020 Real per capita personal income change (%)', 'state_code'],
#       dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    print(avg_income_df[avg_income_df.state_code==state]['2020 Real per capita personal income'])
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['2020 Real per capita personal income'])
  except:
    avg_income_dic[state] = None
avg_income_dic

# %%
general_df["avg_income"] = 0
for i in general_df.index:
  general_df["avg_income"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
general_df

# %% [markdown]
# ## Adding Mean Travel Time

# %%
avg_income_df = pd.read_csv(f"{root_path}/mean_travel_time.csv")
avg_income_df.columns
# Out:
# Index(['State', 'Value', 'state_code'], dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['Value'])
  except:
    avg_income_dic[state] = None
avg_income_dic

# %%
general_df["mean_travel_time"] = 0
for i in general_df.index:
  general_df["mean_travel_time"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Adding precentage above 65

# %%
avg_income_df = pd.read_csv(f"{root_path}/percent_above_65_age.csv")
avg_income_df.columns
# Out:
# Index(['State', 'Value', 'state_code'], dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['Value'])
  except:
    avg_income_dic[state] = None
avg_income_dic

# %%
general_df["above_65"] = 0
for i in general_df.index:
  general_df["above_65"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Adding Percent White

# %%
avg_income_df = pd.read_csv(f"{root_path}/percent_white.csv")
avg_income_df.columns
# Out:
# Index(['State', 'Value', 'state_code'], dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['Value'])
  except:
    avg_income_dic[state] = None
avg_income_dic

# %%
general_df["percent_white"] = 0
for i in general_df.index:
  general_df["percent_white"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Adding Persons per Household

# %%
avg_income_df = pd.read_csv(f"{root_path}/persons_per_household.csv")
avg_income_df.columns
# Out:
# Index(['State', 'Value', 'state_code'], dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['Value'])
  except:
    avg_income_dic[state] = None
avg_income_dic

# %%
general_df["persons_per_household"] = 0
for i in general_df.index:
  general_df["persons_per_household"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %% [markdown]
# ## Adding Percent in Poverty

# %%
avg_income_df = pd.read_csv(f"{root_path}/percent_in_poverty.csv")
avg_income_df.columns
# Out:
# Index(['State', 'Value', 'state_code'], dtype='object')

# %%
avg_income_dic = {}
for state in general_df_states:
  try:
    avg_income_dic[state] = float(avg_income_df[avg_income_df.state_code==state]['Value'])
  except:
    avg_income_dic[state] = None
avg_income_dic
# Out:
# {'AK': 10.9,
#  'AL': 16.8,
#  'AR': 17.2,
#  'AZ': 14.0,
#  'CA': 12.8,
#  'CO': 9.6,
#  'CT': 10.4,
#  'DC': 16.2,
#  'DE': 12.5,
#  'FL': 13.6,
#  'GA': 14.3,
#  'GU': None,
#  'HI': 8.8,
#  'IA': 11.2,
#  'ID': 11.8,
#  'IL': 12.1,
#  'IN': 13.1,
#  'KS': 12.0,
#  'KY': 16.9,
#  'LA': 18.6,
#  'MA': 10.0,
#  'MD': 9.0,
#  'ME': 11.6,
#  'MI': 14.1,
#  'MN': 9.6,
#  'MO': 13.2,
#  'MS': 19.7,
#  'MT': 13.0,
#  'NC': 14.0,
#  'ND': 10.7,
#  'NE': 11.0,
#  'NH': 7.6,
#  'NJ': 9.5,
#  'NM': 19.5,
#  'NV': 12.9,
#  'NY': 13.6,
#  'OH': 13.9,
#  'OK': 15.6,
#  'OR': 12.6,
#  'PA': 12.2,
#  'PR': None,
#  'RI': 12.9,
#  'SC': 15.3,
#  'SD': 13.1,
#  'TN': 15.3,
#  'TX': 14.9,
#  'UT': 9.0,
#  'VA': 10.7,
#  'VI': None,
#  'VT': 11.0,
#  'WA': 10.3,
#  'WI': 11.0,
#  'WV': 17.8,
#  'WY': 11.1}

# %%
general_df["percent_in_poverty"] = 0
for i in general_df.index:
  general_df["percent_in_poverty"][i] = avg_income_dic[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
general_df
# Out:
#             no_of_hospitals  miles_of_road  percent_democrat  population  \
# state_code
# AZ                      107        66968.0         50.000000    14303004
# CO                      105        89207.0         56.000000    11547428
# FL                      252       123487.0         48.000000    43076374
# IA                      123       114838.0         45.000000     6380738
# IN                      166        97110.0         41.000000    13571056
# KY                      114        80006.0         36.000000     9011672
# LA                      209        63746.0         40.000000     9315514
# ME                       38        22851.0         55.000000     2724718
# MI                      158       122040.0         51.000000    20154662
# MN                      139       141956.0         53.000000    11412988
# ND                       48        88429.0         32.000000     1558188
# PR                       58        19916.0               NaN     6571748
# ...

# %%
general_df.to_csv("/content/DSS_project/raw_datasets/combined_general_data.csv")
